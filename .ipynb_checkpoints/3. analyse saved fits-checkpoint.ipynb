# %%
import numpy as np
np.random.seed(42)
import pandas as pd
from sklearn.model_selection import cross_val_predict
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import time

# %%
# time.sleep(1000)

# %%
def get_metrics(y_pred, y_test, to_print=True):
    correct_labels = np.where(y_pred==y_test)[0]
    accuracy = metrics.accuracy_score(y_test, y_pred)
    precision = metrics.precision_score(y_test, y_pred,average='macro')
    recall = metrics.recall_score(y_test, y_pred,average='macro')
    f1score = metrics.f1_score(y_test, y_pred,average='macro')
    # rocscore = metrics.roc_auc_score(y_test, y_pred,average='micro',multi_class="ovo")
    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)  
    classification_report = metrics.classification_report(y_test, y_pred)

    if to_print:
        print("Identified {} correct labels out of {} labels".format(len(correct_labels), y_test.shape[0]))
        print("Accuracy:",accuracy)
        print("Precision:",precision)
        print("Recall:",recall)
        print("F1 Score:",f1score)
        # print("ROC AUC Score:",rocscore)
        print("Confusion Matrix:\n", confusion_matrix)
        print("Classification_Report:\n", classification_report)

#     return (correct_labels, accuracy, precision, recall, confusion_matrix, classification_report)

# %%
def rfcfit(fname):
    print("*****************")
    print(fname)
    
    
    df = pd.read_csv(f"saved_fits/{fname}.csv")
    avgtime = df.dropna()['timetaken'].mean()
    failedobjs = len(df) - len(df.dropna())
    
    print(f"There are {failedobjs} objects for whom at least 1 passband's fit failed.")
    print(f"Average time taken for 1 full object is {avgtime} seconds per object for all 6 passbands")
    df = df.fillna(0)
    X = df[df.columns[3:]].values
    y = df["objclass"].values
    
    rfc = RandomForestClassifier(n_estimators=200,random_state=42)
    preds = cross_val_predict(rfc, X, y, cv=10)
    
    get_metrics(preds,y)
    f1score = metrics.f1_score(preds,y,average='macro')
    
    return avgtime, f1score, failedobjs

# %%
allparams = ["oldbazin","bazin","fred",
             "karpenka","villar","alercev1","alercev2"]
paramname = ["Bazin - old implementation","Bazin - new implementation","FRED",
             "Karpenka","Villar","Alercev1", "Alercev2"]
columnname = ["Parameterisation Used","Average Time per Object for all 6 passbands (s)",
              "Average F1 Score for RFC (n=150)", "Total objects (of 480) where fit failed (for ≥ 1 passband)"]

# %%
summarylist = []
for i, param in enumerate(allparams):
    res = list(rfcfit(param))
    summarylist.append([paramname[i]]+res)
# Out:
# *****************
# oldbazin
# There are 0 objects for whom at least 1 passband's fit failed.
# Average time taken for 1 full object is 0.00814443197515271 seconds per object for all 6 passbands
# Identified 279 correct labels out of 480 labels
# Accuracy: 0.58125
# Precision: 0.5612961875561917
# Recall: 0.58125
# F1 Score: 0.5675510058897013
# Confusion Matrix:
#  [[55  0  0  0  1  0  0  4]
#  [ 1 39  5  2  1  1  5  6]
#  [ 0  4 43  3  0  5  4  1]
#  [ 0  3  1 29 10 13  4  0]
#  [ 0  1  2  8 39  7  3  0]
#  [ 0  2  9 12  6 22  9  0]
#  [ 0 11 13  8 11 12  5  0]
#  [ 1  3  5  1  2  1  0 47]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#          AGN       0.96      0.92      0.94        60
#       SLSN-I       0.62      0.65      0.63        60
#         SNII       0.55      0.72      0.62        60
#         SNIa       0.46      0.48      0.47        60
#    SNIa-91bg       0.56      0.65      0.60        60
#        SNIax       0.36      0.37      0.36        60
#        SNIbc       0.17      0.08      0.11        60
#          TDE       0.81      0.78      0.80        60
#
#     accuracy                           0.58       480
#    macro avg       0.56      0.58      0.57       480
# weighted avg       0.56      0.58      0.57       480
#
# *****************
# bazin
# There are 11 objects for whom at least 1 passband's fit failed.
# Average time taken for 1 full object is 0.03701854065621919 seconds per object for all 6 passbands
# Identified 298 correct labels out of 480 labels
# Accuracy: 0.6208333333333333
# Precision: 0.6113327084334671
# Recall: 0.6208333333333333
# F1 Score: 0.6110697736940032
# Confusion Matrix:
#  [[54  1  1  0  1  0  0  3]
#  [ 1 40  4  4  0  4  2  5]
#  [ 0  5 42  4  3  2  3  1]
#  [ 0  2  1 31 11 11  4  0]
#  [ 0  1  4  7 39  3  5  1]
#  [ 1  1  6 13  5 27  5  2]
#  [ 0  5 10  8 11 12 12  2]
#  [ 0  3  1  0  2  0  1 53]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#          AGN       0.96      0.90      0.93        60
#       SLSN-I       0.69      0.67      0.68        60
#         SNII       0.61      0.70      0.65        60
#         SNIa       0.46      0.52      0.49        60
#    SNIa-91bg       0.54      0.65      0.59        60
#        SNIax       0.46      0.45      0.45        60
#        SNIbc       0.38      0.20      0.26        60
#          TDE       0.79      0.88      0.83        60
#
#     accuracy                           0.62       480
#    macro avg       0.61      0.62      0.61       480
# weighted avg       0.61      0.62      0.61       480
#
# *****************
# fred
# There are 54 objects for whom at least 1 passband's fit failed.
# Average time taken for 1 full object is 0.05150207032993175 seconds per object for all 6 passbands
# Identified 219 correct labels out of 480 labels
# Accuracy: 0.45625
# Precision: 0.45181836057072233
# Recall: 0.45624999999999993
# F1 Score: 0.45314891440704913
# Confusion Matrix:
#  [[50  4  2  1  0  0  0  3]
#  [ 3 26  3  5  6  8  5  4]
#  [ 0  5 34  4  1  3  7  6]
#  [ 0  8  6 14 14  8  7  3]
#  [ 0  3  4 13 22 11  5  2]
#  [ 0  2  5 11  7 20 13  2]
#  [ 1  4 13  8 11 10 12  1]
#  [ 4  5  6  0  0  1  3 41]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#          AGN       0.86      0.83      0.85        60
#       SLSN-I       0.46      0.43      0.44        60
#         SNII       0.47      0.57      0.51        60
#         SNIa       0.25      0.23      0.24        60
#    SNIa-91bg       0.36      0.37      0.36        60
#        SNIax       0.33      0.33      0.33        60
#        SNIbc       0.23      0.20      0.21        60
#          TDE       0.66      0.68      0.67        60
#
#     accuracy                           0.46       480
#    macro avg       0.45      0.46      0.45       480
# weighted avg       0.45      0.46      0.45       480
#
# *****************
# karpenka
# There are 12 objects for whom at least 1 passband's fit failed.
# Average time taken for 1 full object is 0.14043855471828381 seconds per object for all 6 passbands
# Identified 206 correct labels out of 480 labels
# Accuracy: 0.42916666666666664
# Precision: 0.4241271466975403
# Recall: 0.4291666666666667
# F1 Score: 0.4235635520337462
# Confusion Matrix:
#  [[53  1  1  0  1  0  0  4]
#  [ 0 33  3  2  3  6  6  7]
#  [ 0  6 23  8  8  5  2  8]
#  [ 0  5  7 17  6 14  6  5]
#  [ 0  4  7 18 18  9  4  0]
#  [ 0  3  9 12  7 14  8  7]
#  [ 0  5  8 10 12 11  8  6]
#  [ 2  5  7  3  1  0  2 40]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#          AGN       0.96      0.88      0.92        60
#       SLSN-I       0.53      0.55      0.54        60
#         SNII       0.35      0.38      0.37        60
#         SNIa       0.24      0.28      0.26        60
#    SNIa-91bg       0.32      0.30      0.31        60
#        SNIax       0.24      0.23      0.24        60
#        SNIbc       0.22      0.13      0.17        60
#          TDE       0.52      0.67      0.58        60
#
#     accuracy                           0.43       480
#    macro avg       0.42      0.43      0.42       480
# weighted avg       0.42      0.43      0.42       480
#
# *****************
# villar
# There are 0 objects for whom at least 1 passband's fit failed.
# Average time taken for 1 full object is 0.04278931775026847 seconds per object for all 6 passbands
# Identified 208 correct labels out of 480 labels
# Accuracy: 0.43333333333333335
# Precision: 0.42002203045837594
# Recall: 0.4333333333333333
# F1 Score: 0.4255454297131321
# Confusion Matrix:
#  [[51  0  4  1  1  1  0  2]
#  [ 4 31  3  3  1 10  4  4]
#  [ 0  5 25  2  4  6  8 10]
#  [ 1  7  2 17 13 11  4  5]
#  [ 2  6  2 14 17 10  9  0]
#  [ 1  4  8 10  8 17 11  1]
#  [ 0  5 13  7 12 11  7  5]
#  [ 3  4  4  0  2  2  2 43]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#          AGN       0.82      0.85      0.84        60
#       SLSN-I       0.50      0.52      0.51        60
#         SNII       0.41      0.42      0.41        60
#         SNIa       0.31      0.28      0.30        60
#    SNIa-91bg       0.29      0.28      0.29        60
#        SNIax       0.25      0.28      0.27        60
#        SNIbc       0.16      0.12      0.13        60
#          TDE       0.61      0.72      0.66        60
#
#     accuracy                           0.43       480
#    macro avg       0.42      0.43      0.43       480
# weighted avg       0.42      0.43      0.43       480
#
# *****************
# alercev1
# There are 0 objects for whom at least 1 passband's fit failed.
# Average time taken for 1 full object is 0.0547328263521194 seconds per object for all 6 passbands
# Identified 237 correct labels out of 480 labels
# Accuracy: 0.49375
# Precision: 0.4931973560220357
# Recall: 0.49375
# F1 Score: 0.49086099872063693
# Confusion Matrix:
#  [[41  2  4  2  0  0  3  8]
#  [ 1 37  1  3  2  3  7  6]
#  [ 1  3 31  4  3  4  9  5]
#  [ 0  4  2 25 11  8  7  3]
#  [ 1  6  8  8 26  6  4  1]
#  [ 0  7  8 10  1 21 11  2]
#  [ 0  2  9  9  9 17 10  4]
#  [ 5  4  1  1  0  1  2 46]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#          AGN       0.84      0.68      0.75        60
#       SLSN-I       0.57      0.62      0.59        60
#         SNII       0.48      0.52      0.50        60
#         SNIa       0.40      0.42      0.41        60
#    SNIa-91bg       0.50      0.43      0.46        60
#        SNIax       0.35      0.35      0.35        60
#        SNIbc       0.19      0.17      0.18        60
#          TDE       0.61      0.77      0.68        60
#
#     accuracy                           0.49       480
#    macro avg       0.49      0.49      0.49       480
# weighted avg       0.49      0.49      0.49       480
#
# *****************
# alercev2
# There are 10 objects for whom at least 1 passband's fit failed.
# Average time taken for 1 full object is 0.09500126094682838 seconds per object for all 6 passbands
# Identified 237 correct labels out of 480 labels
# Accuracy: 0.49375
# Precision: 0.47737287610592094
# Recall: 0.49374999999999997
# F1 Score: 0.4816906830492269
# Confusion Matrix:
#  [[41  1  4  1  1  1  0 11]
#  [ 2 35  3  4  1  4  4  7]
#  [ 0  7 35  3  5  3  4  3]
#  [ 0  5  3 26 11  7  8  0]
#  [ 5  5  2  6 33  3  5  1]
#  [ 1  6 11 11  5 16  8  2]
#  [ 1  5 12 11  9 12  7  3]
#  [ 3  2  6  1  2  1  1 44]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#          AGN       0.77      0.68      0.73        60
#       SLSN-I       0.53      0.58      0.56        60
#         SNII       0.46      0.58      0.51        60
#         SNIa       0.41      0.43      0.42        60
#    SNIa-91bg       0.49      0.55      0.52        60
#        SNIax       0.34      0.27      0.30        60
#        SNIbc       0.19      0.12      0.14        60
#          TDE       0.62      0.73      0.67        60
#
#     accuracy                           0.49       480
#    macro avg       0.48      0.49      0.48       480
# weighted avg       0.48      0.49      0.48       480

# %% [markdown]
# # SUMMARY

# %%
summarydf = pd.DataFrame(data=summarylist,columns=columnname) 
summarydf.style.set_properties(align="right")
# Out:
# <style  type="text/css" >
# #T_11b49_row0_col0,#T_11b49_row0_col1,#T_11b49_row0_col2,#T_11b49_row0_col3,#T_11b49_row1_col0,#T_11b49_row1_col1,#T_11b49_row1_col2,#T_11b49_row1_col3,#T_11b49_row2_col0,#T_11b49_row2_col1,#T_11b49_row2_col2,#T_11b49_row2_col3,#T_11b49_row3_col0,#T_11b49_row3_col1,#T_11b49_row3_col2,#T_11b49_row3_col3,#T_11b49_row4_col0,#T_11b49_row4_col1,#T_11b49_row4_col2,#T_11b49_row4_col3,#T_11b49_row5_col0,#T_11b49_row5_col1,#T_11b49_row5_col2,#T_11b49_row5_col3,#T_11b49_row6_col0,#T_11b49_row6_col1,#T_11b49_row6_col2,#T_11b49_row6_col3{
#             align:  right;
#         }</style><table id="T_11b49_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Parameterisation Used</th>        <th class="col_heading level0 col1" >Average Time per Object for all 6 passbands (s)</th>        <th class="col_heading level0 col2" >Average F1 Score for RFC (n=150)</th>        <th class="col_heading level0 col3" >Total objects (of 480) where fit failed (for ≥ 1 passband)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11b49_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_11b49_row0_col0" class="data row0 col0" >Bazin - old implementation</td>
#                         <td id="T_11b49_row0_col1" class="data row0 col1" >0.008144</td>
#                         <td id="T_11b49_row0_col2" class="data row0 col2" >0.567551</td>
#                         <td id="T_11b49_row0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_11b49_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_11b49_row1_col0" class="data row1 col0" >Bazin - new implementation</td>
#                         <td id="T_11b49_row1_col1" class="data row1 col1" >0.037019</td>
#                         <td id="T_11b49_row1_col2" class="data row1 col2" >0.611070</td>
#                         <td id="T_11b49_row1_col3" class="data row1 col3" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_11b49_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_11b49_row2_col0" class="data row2 col0" >FRED</td>
#                         <td id="T_11b49_row2_col1" class="data row2 col1" >0.051502</td>
#                         <td id="T_11b49_row2_col2" class="data row2 col2" >0.453149</td>
#                         <td id="T_11b49_row2_col3" class="data row2 col3" >54</td>
#             </tr>
#             <tr>
#                         <th id="T_11b49_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_11b49_row3_col0" class="data row3 col0" >Karpenka</td>
#                         <td id="T_11b49_row3_col1" class="data row3 col1" >0.140439</td>
#                         <td id="T_11b49_row3_col2" class="data row3 col2" >0.423564</td>
#                         <td id="T_11b49_row3_col3" class="data row3 col3" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_11b49_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_11b49_row4_col0" class="data row4 col0" >Villar</td>
#                         <td id="T_11b49_row4_col1" class="data row4 col1" >0.042789</td>
#                         <td id="T_11b49_row4_col2" class="data row4 col2" >0.425545</td>
#                         <td id="T_11b49_row4_col3" class="data row4 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_11b49_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_11b49_row5_col0" class="data row5 col0" >Alercev1</td>
#                         <td id="T_11b49_row5_col1" class="data row5 col1" >0.054733</td>
#                         <td id="T_11b49_row5_col2" class="data row5 col2" >0.490861</td>
#                         <td id="T_11b49_row5_col3" class="data row5 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_11b49_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_11b49_row6_col0" class="data row6 col0" >Alercev2</td>
#                         <td id="T_11b49_row6_col1" class="data row6 col1" >0.095001</td>
#                         <td id="T_11b49_row6_col2" class="data row6 col2" >0.481691</td>
#                         <td id="T_11b49_row6_col3" class="data row6 col3" >10</td>
#             </tr>
#     </tbody></table>

# %%
print(summarydf.to_markdown())
# Out:
# |    | Parameterisation Used      |   Average Time per Object for all 6 passbands (s) |   Average F1 Score for RFC (n=150) |   Total objects (of 480) where fit failed (for ≥ 1 passband) |
# |---:|:---------------------------|--------------------------------------------------:|-----------------------------------:|-------------------------------------------------------------:|
# |  0 | Bazin - old implementation |                                        0.00814443 |                           0.567551 |                                                            0 |
# |  1 | Bazin - new implementation |                                        0.0370185  |                           0.61107  |                                                           11 |
# |  2 | FRED                       |                                        0.0515021  |                           0.453149 |                                                           54 |
# |  3 | Karpenka                   |                                        0.140439   |                           0.423564 |                                                           12 |
# |  4 | Villar                     |                                        0.0427893  |                           0.425545 |                                                            0 |
# |  5 | Alercev1                   |                                        0.0547328  |                           0.490861 |                                                            0 |
# |  6 | Alercev2                   |                                        0.0950013  |                           0.481691 |                                                           10 |

# %% [markdown]
# <!-- |Parameterisation Used| Average Time per Object for all   6 passbands (s) | Average F1 Score for RFC (n=150) | Total objects (of 480) where fit failed   (for ≥ 1 passband) |   |
# |:----------------------:|:---------------------------------------------------:|:----------------:|:------------------------------------------------------:|---|
# | Bazin                  | 0.0309                                              | 0.56 ± 0.02      | 11                                                     |   |
# | FRED                   | 0.0452                                              | 0.47 ± 0.02      | 54                                                    |   |
# | Alerce: Sid Guesses    | 0.0789                                              | 0.47 ± 0.02      | 10                                                     |   |
# | Alerce: Alerce Guesses | 0.0947                                              | 0.47 ± 0.02      | 10                                                     |   |
# | Alerce: Using R        | 0.0952                                              | 0.45 ± 0.02      | 13                                                     |   |
# | Villar                 | 0.0375                                              | 0.50 ± 0.02      | 0                                                      |   | -->
